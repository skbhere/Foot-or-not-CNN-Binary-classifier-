# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
import pandas as pd
import numpy as np

# %%
print(len(os.listdir('/content/drive/My Drive/data/foot or not/0foot/')))
print(len(os.listdir('/content/drive/My Drive/data/foot or not/not foot/')))
# Out:
# 673
# 673

# %%
to_create = [
    '/content/drive/My Drive/data/foot or not/training',
    '/content/drive/My Drive/data/foot or not/testing',
    '/content/drive/My Drive/data/foot or not/training/0foot',
    '/content/drive/My Drive/data/foot or not/training/not_foot',
    '/content/drive/My Drive/data/foot or not/testing/0foot',
    '/content/drive/My Drive/data/foot or not/testing/not_foot'
]
for directory in to_create:
    try:
        os.mkdir(directory)
        print(directory, 'created')
    except:
        print(directory, 'failed')
# Out:
# /content/drive/My Drive/data/foot or not/training created
# /content/drive/My Drive/data/foot or not/testing created
# /content/drive/My Drive/data/foot or not/training/0foot created
# /content/drive/My Drive/data/foot or not/training/not_foot created
# /content/drive/My Drive/data/foot or not/testing/0foot created
# /content/drive/My Drive/data/foot or not/testing/not_foot created

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    all_files = []
    
    for file_name in os.listdir(SOURCE):
        file_path = SOURCE + file_name

        if os.path.getsize(file_path):
            all_files.append(file_name)
        else:
            print('{} is zero length, so ignoring'.format(file_name))
    
    n_files = len(all_files)
    split_point = int(n_files * SPLIT_SIZE)
    
    shuffled = random.sample(all_files, n_files)
    
    train_set = shuffled[:split_point]
    test_set = shuffled[split_point:]
    
    for file_name in train_set:
        copyfile(SOURCE + file_name, TRAINING + file_name)
        
    for file_name in test_set:
        copyfile(SOURCE + file_name, TESTING + file_name)

FOOT_SOURCE_DIR = r"/content/drive/My Drive/data/foot or not/0foot/"
TRAINING_FOOT_DIR = r"/content/drive/My Drive/data/foot or not/training/0foot/"
TESTING_FOOT_DIR = r"/content/drive/My Drive/data/foot or not/testing/0foot/"
NOT_FOOT_SOURCE_DIR = r"/content/drive/My Drive/data/foot or not/not foot/"
TRAINING_NOT_FOOT_DIR = r"/content/drive/My Drive/data/foot or not/training/not_foot/"
TESTING_NOT_FOOT_DIR = r"/content/drive/My Drive/data/foot or not/testing/not_foot/"

split_size = .9
split_data(FOOT_SOURCE_DIR, TRAINING_FOOT_DIR, TESTING_FOOT_DIR, split_size)
split_data(NOT_FOOT_SOURCE_DIR, TRAINING_NOT_FOOT_DIR, TESTING_NOT_FOOT_DIR, split_size)

# %%
print(len(os.listdir('/content/drive/My Drive/data/foot or not/training/0foot/')))
print(len(os.listdir('/content/drive/My Drive/data/foot or not/training/not_foot/')))
print(len(os.listdir('/content/drive/My Drive/data/foot or not/testing/0foot/')))
print(len(os.listdir('/content/drive/My Drive/data/foot or not/testing/not_foot/')))
# Out:
# 605
# 605
# 68
# 68

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (2,2), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer="Adamax", loss='binary_crossentropy', metrics=['acc'])

# %%
TRAINING_DIR = '/content/drive/My Drive/data/foot or not/training/'
train_datagen = ImageDataGenerator(
    rescale=1 / 255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=.2,
    zoom_range=.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    batch_size=64,
    class_mode='binary',
    target_size=(150, 150)
)

VALIDATION_DIR = '/content/drive/My Drive/data/foot or not/testing/'
validation_datagen = ImageDataGenerator(
    rescale=1 / 255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=.2,
    zoom_range=.2,
    horizontal_flip=True,
    fill_mode='nearest'

)
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    batch_size=64,
    class_mode='binary',
    target_size=(150, 150)
)
# Out:
# Found 263 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.

# %%
# import warnings
# warnings.filterwarnings('ignore')
# print('warnings ignored')
# Out:
# warnings ignored

# %%
history = model.fit_generator(
    train_generator,
    epochs=50,
    verbose=1,
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 7s 1s/step - loss: 2.4457 - acc: 0.6426 - val_loss: 0.7410 - val_acc: 0.2000
# Epoch 2/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.7192 - acc: 0.2738 - val_loss: 0.6881 - val_acc: 0.8333
# Epoch 3/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.6588 - acc: 0.7376 - val_loss: 0.5812 - val_acc: 0.8333
# Epoch 4/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.6175 - acc: 0.7376 - val_loss: 0.5164 - val_acc: 0.8333
# Epoch 5/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.6156 - acc: 0.7376 - val_loss: 0.4935 - val_acc: 0.8333
# Epoch 6/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.6141 - acc: 0.7376 - val_loss: 0.4783 - val_acc: 0.8333
# Epoch 7/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5993 - acc: 0.7376 - val_loss: 0.4799 - val_acc: 0.8333
# Epoch 8/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5840 - acc: 0.7376 - val_loss: 0.4804 - val_acc: 0.8333
# Epoch 9/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5693 - acc: 0.7376 - val_loss: 0.4721 - val_acc: 0.8333
# Epoch 10/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5462 - acc: 0.7376 - val_loss: 0.4192 - val_acc: 0.8333
# Epoch 11/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5394 - acc: 0.7376 - val_loss: 0.4006 - val_acc: 0.8333
# Epoch 12/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.5100 - acc: 0.7376 - val_loss: 0.3763 - val_acc: 0.8333
# Epoch 13/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.5019 - acc: 0.7376 - val_loss: 0.3646 - val_acc: 0.8333
# Epoch 14/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4777 - acc: 0.7376 - val_loss: 0.3331 - val_acc: 0.8333
# Epoch 15/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.4578 - acc: 0.7376 - val_loss: 0.3328 - val_acc: 0.8333
# Epoch 16/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.4355 - acc: 0.7338 - val_loss: 0.2813 - val_acc: 0.8333
# Epoch 17/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.4107 - acc: 0.7681 - val_loss: 0.2705 - val_acc: 0.9000
# Epoch 18/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.3735 - acc: 0.8213 - val_loss: 0.2162 - val_acc: 0.9667
# Epoch 19/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.3594 - acc: 0.8403 - val_loss: 0.2189 - val_acc: 0.9333
# Epoch 20/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.3610 - acc: 0.8593 - val_loss: 0.2251 - val_acc: 0.9667
# Epoch 21/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.3422 - acc: 0.8669 - val_loss: 0.2003 - val_acc: 0.9667
# Epoch 22/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.2958 - acc: 0.8859 - val_loss: 0.1895 - val_acc: 0.9667
# Epoch 23/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.2941 - acc: 0.8745 - val_loss: 0.1946 - val_acc: 0.9667
# Epoch 24/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.2934 - acc: 0.8859 - val_loss: 0.1548 - val_acc: 0.9667
# Epoch 25/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.2649 - acc: 0.9202 - val_loss: 0.1598 - val_acc: 0.9667
# Epoch 26/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.2842 - acc: 0.8745 - val_loss: 0.1427 - val_acc: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.2294 - acc: 0.9202 - val_loss: 0.0934 - val_acc: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.2480 - acc: 0.9087 - val_loss: 0.1061 - val_acc: 0.9667
# Epoch 29/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.2205 - acc: 0.9087 - val_loss: 0.0905 - val_acc: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.2138 - acc: 0.9202 - val_loss: 0.1250 - val_acc: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1934 - acc: 0.9392 - val_loss: 0.1162 - val_acc: 0.9667
# Epoch 32/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1989 - acc: 0.9049 - val_loss: 0.0765 - val_acc: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1821 - acc: 0.9240 - val_loss: 0.0683 - val_acc: 0.9667
# Epoch 34/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1931 - acc: 0.9049 - val_loss: 0.1155 - val_acc: 0.9667
# Epoch 35/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1749 - acc: 0.9506 - val_loss: 0.0873 - val_acc: 0.9667
# Epoch 36/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1618 - acc: 0.9430 - val_loss: 0.0979 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1769 - acc: 0.9202 - val_loss: 0.0688 - val_acc: 0.9667
# Epoch 38/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1633 - acc: 0.9163 - val_loss: 0.0715 - val_acc: 0.9667
# Epoch 39/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1432 - acc: 0.9354 - val_loss: 0.0917 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1622 - acc: 0.9468 - val_loss: 0.0938 - val_acc: 0.9667
# Epoch 41/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1390 - acc: 0.9392 - val_loss: 0.0797 - val_acc: 0.9667
# Epoch 42/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1850 - acc: 0.9011 - val_loss: 0.0585 - val_acc: 0.9667
# Epoch 43/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1605 - acc: 0.9202 - val_loss: 0.1180 - val_acc: 0.9667
# Epoch 44/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1444 - acc: 0.9544 - val_loss: 0.1107 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1306 - acc: 0.9696 - val_loss: 0.0883 - val_acc: 0.9667
# Epoch 46/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1460 - acc: 0.9430 - val_loss: 0.0982 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.1389 - acc: 0.9430 - val_loss: 0.0387 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1183 - acc: 0.9582 - val_loss: 0.0802 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.1014 - acc: 0.9582 - val_loss: 0.0872 - val_acc: 0.9667
# Epoch 50/50
# 5/5 [==============================] - 7s 1s/step - loss: 0.1352 - acc: 0.9506 - val_loss: 0.1300 - val_acc: 1.0000

# %%
# PLOT LOSS AND ACCURACY
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b' )
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r' )
plt.plot(epochs, val_loss, 'b')


plt.title('Training and validation loss')

# Desired output. Charts with training and validation metrics. No crash :)
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
# Here's a codeblock just for fun. You should be able to upload an image here 
# and have it classified without crashing

import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
    # predicting images
    path = '/content/' + fn
    img = image.load_img(path, target_size=(150, 150))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=10)
    print(classes[0][0])
    if classes[0][0]>0.5:
        print(fn + " is Foot")
    else:
        print(fn + " is not a Foot")
# Out:
#      <input type="file" id="files-4f8d25cf-ceb7-4a21-87b5-95f411e00fb2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f8d25cf-ceb7-4a21-87b5-95f411e00fb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdobeStock_245471467.jpeg to AdobeStock_245471467 (6).jpeg
# 1.0
# AdobeStock_245471467.jpeg is Foot
